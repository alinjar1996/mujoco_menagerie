# %%
# !pip install numpy
# !pip install mediapy
# !pip install tqdm
# !pip install mujoco
from dataclasses import dataclass
import numpy as np
import mediapy as media
from pathlib import Path
import enum
from tqdm import tqdm
import mujoco
# Out:
# Requirement already satisfied: numpy in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (2.2.5)
# Requirement already satisfied: mediapy in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (1.2.3)
# Requirement already satisfied: ipython in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from mediapy) (8.35.0)
# Requirement already satisfied: matplotlib in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from mediapy) (3.10.1)
# Requirement already satisfied: numpy in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from mediapy) (2.2.5)
# Requirement already satisfied: Pillow in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from mediapy) (11.2.1)
# Requirement already satisfied: decorator in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from ipython->mediapy) (5.2.1)
# Requirement already satisfied: exceptiongroup in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from ipython->mediapy) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from ipython->mediapy) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from ipython->mediapy) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from ipython->mediapy) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from ipython->mediapy) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from ipython->mediapy) (2.19.1)
# Requirement already satisfied: stack_data in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from ipython->mediapy) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from ipython->mediapy) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from ipython->mediapy) (4.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from matplotlib->mediapy) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from matplotlib->mediapy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from matplotlib->mediapy) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from matplotlib->mediapy) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from matplotlib->mediapy) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from matplotlib->mediapy) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from matplotlib->mediapy) (2.9.0.post0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from jedi>=0.16->ipython->mediapy) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from pexpect>4.3->ipython->mediapy) (0.7.0)
# Requirement already satisfied: wcwidth in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->mediapy) (0.2.13)
# Requirement already satisfied: six>=1.5 in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mediapy) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from stack_data->ipython->mediapy) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from stack_data->ipython->mediapy) (3.0.0)
# Requirement already satisfied: pure-eval in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from stack_data->ipython->mediapy) (0.2.3)
# Requirement already satisfied: tqdm in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (4.67.1)
# Collecting mujoco
#   Using cached mujoco-3.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
# Collecting absl-py (from mujoco)
#   Using cached absl_py-2.2.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting etils[epath] (from mujoco)
#   Using cached etils-1.12.2-py3-none-any.whl.metadata (6.5 kB)
# Collecting glfw (from mujoco)
#   Using cached glfw-2.9.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from mujoco) (2.2.5)
# Collecting pyopengl (from mujoco)
#   Using cached PyOpenGL-3.1.9-py3-none-any.whl.metadata (3.3 kB)
# Collecting fsspec (from etils[epath]->mujoco)
#   Using cached fsspec-2025.3.2-py3-none-any.whl.metadata (11 kB)
# Collecting importlib_resources (from etils[epath]->mujoco)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing_extensions in /home/ims/mjx_manipulator/MJX_go1/.venv/lib/python3.10/site-packages (from etils[epath]->mujoco) (4.13.2)
# Collecting zipp (from etils[epath]->mujoco)
#   Using cached zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Using cached mujoco-3.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
# Using cached absl_py-2.2.2-py3-none-any.whl (135 kB)
# Using cached glfw-2.9.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl (243 kB)
# Using cached PyOpenGL-3.1.9-py3-none-any.whl (3.2 MB)
# Using cached etils-1.12.2-py3-none-any.whl (167 kB)
# Using cached fsspec-2025.3.2-py3-none-any.whl (194 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Installing collected packages: pyopengl, glfw, zipp, importlib_resources, fsspec, etils, absl-py, mujoco
# Successfully installed absl-py-2.2.2 etils-1.12.2 fsspec-2025.3.2 glfw-2.9.0 importlib_resources-6.5.2 mujoco-3.3.1 pyopengl-3.1.9 zipp-3.21.0

# %% [markdown]
# ## Helper methods

# %%
class Resolution(enum.Enum):
  SD = (480, 640)
  HD = (720, 1280)
  UHD = (2160, 3840)


def quartic(t: float) -> float:
  return 0 if abs(t) > 1 else (1 - t**2) ** 2


def blend_coef(t: float, duration: float, std: float) -> float:
  normalised_time = 2 * t / duration - 1
  return quartic(normalised_time / std)


def unit_smooth(normalised_time: float) -> float:
  return 1 - np.cos(normalised_time * 2 * np.pi)


def azimuth(
    time: float, duration: float, total_rotation: float, offset: float
) -> float:
  return offset + unit_smooth(time / duration) * total_rotation

# %% [markdown]
# ## Parameters

# %%
res = Resolution.SD
fps = 60
duration = 10.0
ctrl_rate = 2
ctrl_std = 0.05
total_rot = 60
blend_std = .8

# %%
h, w = res.value

# %% [markdown]
# ## Loading and rendering the model

# %%
model_dir = Path("unitree_go1")
model_xml = model_dir / "scene.xml"

# %%
# Load model.
model = mujoco.MjModel.from_xml_path(str(model_xml))
data = mujoco.MjData(model)

# Make sure offscreen rendering can support the desired resolution.
model.vis.global_.offheight = h
model.vis.global_.offwidth = w

renderer = mujoco.Renderer(model, height=h, width=w)

# %%
mujoco.mj_forward(model, data)
renderer.update_scene(data)
media.show_image(renderer.render())
# Out:
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="640" height="480" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>

# %% [markdown]
# ## Checking for keyframes

# %%
for key in range(model.nkey):
  mujoco.mj_resetDataKeyframe(model, data, key)
  mujoco.mj_forward(model, data)
  renderer.update_scene(data)
  media.show_image(renderer.render())

# %% [markdown]
# ## Render!

# %%
np.random.seed(12345)

# Rendering options for visual and collision geoms.
vis = mujoco.MjvOption()
vis.geomgroup[2] = True
vis.geomgroup[3] = False
coll = mujoco.MjvOption()
coll.geomgroup[2] = False
coll.geomgroup[3] = True
coll.flags[mujoco.mjtVisFlag.mjVIS_CONVEXHULL] = True

# Create a camera that will revolve around the robot.
camera = mujoco.MjvCamera()
mujoco.mjv_defaultFreeCamera(model, camera)
camera.distance = 1
offset = model.vis.global_.azimuth

# Sample actuator noise and smooth it.
nsteps = int(np.ceil(duration / model.opt.timestep))
perturb = np.random.randn(nsteps, model.nu)
width = int(nsteps * ctrl_rate / duration)
kernel = np.exp(-0.5 * np.linspace(-3, 3, width) ** 2)
kernel /= np.linalg.norm(kernel)
for i in range(model.nu):
  perturb[:, i] = np.convolve(perturb[:, i], kernel, mode="same")

# Set the desired control point.
if model.nkey > 0:
  mujoco.mj_resetDataKeyframe(model, data, 0)
  ctrl0 = data.ctrl.copy()
else:
  mujoco.mj_resetData(model, data)
  ctrl0 = np.mean(model.actuator_ctrlrange, axis=1)

frames = []
for i in tqdm(range(nsteps)):
  data.ctrl[:] = ctrl0 + ctrl_std * perturb[i]
  mujoco.mj_step(model, data)
  if len(frames) < data.time * fps:
    camera.azimuth = azimuth(data.time, duration, total_rot, offset)
    renderer.update_scene(data, camera, scene_option=vis)
    vispix = renderer.render().copy().astype(np.float32)
    renderer.update_scene(data, camera, scene_option=coll)
    collpix = renderer.render().copy().astype(np.float32)
    b = blend_coef(data.time, duration, blend_std)
    frame = (1 - b) * vispix + b * collpix
    frame = frame.astype(np.uint8)
    frames.append(frame)
media.show_video(frames, fps=fps, loop=False)
